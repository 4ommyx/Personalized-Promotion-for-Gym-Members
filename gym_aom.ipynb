# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("valakhorasani/gym-members-exercise-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/gym-members-exercise-dataset

# %%
import os
print(os.listdir(path))
# Out:
# ['gym_members_exercise_tracking.csv']

# %%
import pandas as pd
df = pd.read_csv(path + "/gym_members_exercise_tracking.csv")
df
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56    Male         88.3        1.71      180      157           60
# 1     46  Female         74.9        1.53      179      151           66
# 2     32  Female         68.1        1.66      167      122           54
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                        1.69           1313.0         Yoga            12.6
# 1                        1.30            883.0         HIIT            33.9
# 2                        1.11            677.0       Cardio            33.4
# 3                        0.59            532.0     Strength            28.8
# 4                        0.64            556.0     Strength            29.2
# ..                        ...              ...          ...             ...
# 968                      1.57           1364.0     Strength            10.0
# 969                      1.38           1260.0     Strength            25.0
# 970                      1.72            929.0       Cardio            18.8
# 971                      1.10            883.0         HIIT            28.2
# 972                      0.75            542.0     Strength            28.8
#
#      Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# 0                      3.5                              4                 3
# 1                      2.1                              4                 2
# 2                      2.3                              4                 2
# 3                      2.1                              3                 1
# 4                      2.8                              3                 1
# ..                     ...                            ...               ...
# 968                    3.5                              4                 3
# 969                    3.0                              2                 1
# 970                    2.7                              5                 3
# 971                    2.1                              3                 2
# 972                    3.5                              2                 1
#
#        BMI
# 0    30.20
# 1    32.00
# 2    24.71
# 3    18.41
# 4    14.39
# ..     ...
# 968  28.77
# 969  25.69
# 970  19.50
# 971  37.74
# 972  33.38
#
# [973 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 973 entries, 0 to 972
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            973 non-null    int64
#  1   Gender                         973 non-null    object
#  2   Weight (kg)                    973 non-null    float64
#  3   Height (m)                     973 non-null    float64
#  4   Max_BPM                        973 non-null    int64
#  5   Avg_BPM                        973 non-null    int64
#  6   Resting_BPM                    973 non-null    int64
#  7   Session_Duration (hours)       973 non-null    float64
#  8   Calories_Burned                973 non-null    float64
#  9   Workout_Type                   973 non-null    object
#  10  Fat_Percentage                 973 non-null    float64
#  11  Water_Intake (liters)          973 non-null    float64
#  12  Workout_Frequency (days/week)  973 non-null    int64
#  13  Experience_Level               973 non-null    int64
#  14  BMI                            973 non-null    float64
# dtypes: float64(7), int64(6), object(2)
# memory usage: 114.2+ KB

# %%
df.describe()
# Out:
#               Age  Weight (kg)  Height (m)     Max_BPM     Avg_BPM  \
# count  973.000000   973.000000   973.00000  973.000000  973.000000
# mean    38.683453    73.854676     1.72258  179.883864  143.766701
# std     12.180928    21.207500     0.12772   11.525686   14.345101
# min     18.000000    40.000000     1.50000  160.000000  120.000000
# 25%     28.000000    58.100000     1.62000  170.000000  131.000000
# 50%     40.000000    70.000000     1.71000  180.000000  143.000000
# 75%     49.000000    86.000000     1.80000  190.000000  156.000000
# max     59.000000   129.900000     2.00000  199.000000  169.000000
#
#        Resting_BPM  Session_Duration (hours)  Calories_Burned  Fat_Percentage  \
# count   973.000000                973.000000       973.000000      973.000000
# mean     62.223022                  1.256423       905.422405       24.976773
# std       7.327060                  0.343033       272.641516        6.259419
# min      50.000000                  0.500000       303.000000       10.000000
# 25%      56.000000                  1.040000       720.000000       21.300000
# 50%      62.000000                  1.260000       893.000000       26.200000
# 75%      68.000000                  1.460000      1076.000000       29.300000
# max      74.000000                  2.000000      1783.000000       35.000000
#
#        Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# count             973.000000                     973.000000        973.000000
# mean                2.626619                       3.321686          1.809866
# std                 0.600172                       0.913047          0.739693
# min                 1.500000                       2.000000          1.000000
# 25%                 2.200000                       3.000000          1.000000
# 50%                 2.600000                       3.000000          2.000000
# 75%                 3.100000                       4.000000          2.000000
# max                 3.700000                       5.000000          3.000000
#
#               BMI
# count  973.000000
# mean    24.912127
# std      6.660879
# min     12.320000
# 25%     20.110000
# 50%     24.160000
# 75%     28.560000
# max     49.840000

# %%
df.isnull().sum()
# Out:
# Age                              0
# Gender                           0
# Weight (kg)                      0
# Height (m)                       0
# Max_BPM                          0
# Avg_BPM                          0
# Resting_BPM                      0
# Session_Duration (hours)         0
# Calories_Burned                  0
# Workout_Type                     0
# Fat_Percentage                   0
# Water_Intake (liters)            0
# Workout_Frequency (days/week)    0
# Experience_Level                 0
# BMI                              0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# selcet nummerical col
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Calcu Correlation Matrix
corr_matrix = numeric_df.corr()
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='Blues', fmt='.2f', linewidths=0.5, mask=mask)
plt.title('Correlation Matrix (Upper Triangle with Blue Colors)')
plt.show()

# %%
## Select Feature (Feature Importance)
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

## Pred (Experience_Level)
X = df.drop(columns=['Experience_Level'])
y = df['Experience_Level']

# trans categorical features
le = LabelEncoder()
X['Gender'] = le.fit_transform(X['Gender'])
X['Workout_Type'] = le.fit_transform(X['Workout_Type'])

X_raw = X.copy()

### dataset to feature importance ###
X_train_df, X_test_df, y_train_df, y_test_df = train_test_split(X_raw, y, test_size=0.2, random_state=42)

# %%
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train_df, y_train_df)

# Feature importance
importances = rf_model.feature_importances_
feature_names = X_raw.columns

df_importance = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

plt.figure(figsize=(12, 10))
plt.barh(df_importance['Feature'], df_importance['Importance'])
plt.gca().invert_yaxis()
plt.title('Feature Importance for Predicting Experience_Level')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()

# %%
import time
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.model_selection import ParameterGrid

# Select top 4 Feature Selection
top_features = df_importance['Feature'].tolist()[:4]
X_train_top = X_train_df[top_features]
X_test_top = X_test_df[top_features]

# Scaling
scaler = StandardScaler()
X_train_top_scaled = scaler.fit_transform(X_train_top)
X_test_top_scaled = scaler.transform(X_test_top)

# train model (KNN, D-tree, SVM, RF)
results = []

# KNN
knn = KNeighborsClassifier(weights='distance')
param_grid_knn = {'n_neighbors': range(1, 16)}
grid_knn = GridSearchCV(knn, param_grid_knn, cv=5, scoring='accuracy')
grid_knn.fit(X_train_top_scaled, y_train_df)
best_knn = grid_knn.best_estimator_

start_train = time.perf_counter()
best_knn.fit(X_train_top_scaled, y_train_df)
end_train = time.perf_counter()

start_pred = time.perf_counter()
y_pred_knn = best_knn.predict(X_test_top_scaled)
end_pred = time.perf_counter()

results.append({
    'Model': 'KNN',
    'Accuracy': accuracy_score(y_test_df, y_pred_knn),
    'Train Time': end_train - start_train,
    'Predict Time': end_pred - start_pred,
    'Report': classification_report(y_test_df, y_pred_knn, output_dict=True),
    'y_pred': y_pred_knn
})

# Random Forest
rf = RandomForestClassifier(random_state=42)

start_train = time.perf_counter()
rf.fit(X_train_top, y_train_df)
end_train = time.perf_counter()

start_pred = time.perf_counter()
y_pred_rf = rf.predict(X_test_top)
end_pred = time.perf_counter()

results.append({
    'Model': 'Random Forest',
    'Accuracy': accuracy_score(y_test_df, y_pred_rf),
    'Train Time': end_train - start_train,
    'Predict Time': end_pred - start_pred,
    'Report': classification_report(y_test_df, y_pred_rf, output_dict=True),
    'y_pred': y_pred_rf
})

# Decision Tree
dt = DecisionTreeClassifier(random_state=42)

start_train = time.perf_counter()
dt.fit(X_train_top, y_train_df)
end_train = time.perf_counter()

start_pred = time.perf_counter()
y_pred_dt = dt.predict(X_test_top)
end_pred = time.perf_counter()

results.append({
    'Model': 'Decision Tree',
    'Accuracy': accuracy_score(y_test_df, y_pred_dt),
    'Train Time': end_train - start_train,
    'Predict Time': end_pred - start_pred,
    'Report': classification_report(y_test_df, y_pred_dt, output_dict=True),
    'y_pred': y_pred_dt
})

# SVM
svm = SVC(kernel='linear')

start_train = time.perf_counter()
svm.fit(X_train_top_scaled, y_train_df)
end_train = time.perf_counter()

start_pred = time.perf_counter()
y_pred_svm = svm.predict(X_test_top_scaled)
end_pred = time.perf_counter()

results.append({
    'Model': 'SVM',
    'Accuracy': accuracy_score(y_test_df, y_pred_svm),
    'Train Time': end_train - start_train,
    'Predict Time': end_pred - start_pred,
    'Report': classification_report(y_test_df, y_pred_svm, output_dict=True),
    'y_pred': y_pred_svm
})

# Summary all model
results_df = pd.DataFrame({
    'Model': [r['Model'] for r in results],
    'Accuracy': [r['Accuracy'] for r in results],
    'Train Time (s)': [r['Train Time'] for r in results],
    'Predict Time (s)': [r['Predict Time'] for r in results]
})

print("\n=== Model Performance Summary ===")
print(results_df)

for r in results:
    print(f"\n--- {r['Model']} Classification Report ---")
    print(classification_report(y_test_df, r['y_pred']))
# Out:
# === Model Performance Summary ===
#            Model  Accuracy  Train Time (s)  Predict Time (s)
# 0            KNN  0.897436        0.001112          0.002090
# 1  Random Forest  0.892308        0.198997          0.011042
# 2  Decision Tree  0.882051        0.004462          0.001266
# 3            SVM  0.892308        0.006571          0.001466
#
# --- KNN Classification Report ---
#               precision    recall  f1-score   support
#
#            1       0.90      0.83      0.87        78
#            2       0.84      0.91      0.87        75
#            3       1.00      1.00      1.00        42
#
#     accuracy                           0.90       195
#    macro avg       0.91      0.91      0.91       195
# weighted avg       0.90      0.90      0.90       195
#
#
# --- Random Forest Classification Report ---
#               precision    recall  f1-score   support
#
#            1       0.91      0.81      0.86        78
#            2       0.82      0.92      0.87        75
#            3       1.00      1.00      1.00        42
#
#     accuracy                           0.89       195
#    macro avg       0.91      0.91      0.91       195
# weighted avg       0.90      0.89      0.89       195
#
#
# --- Decision Tree Classification Report ---
#               precision    recall  f1-score   support
#
#            1       0.88      0.82      0.85        78
#            2       0.82      0.88      0.85        75
#            3       1.00      1.00      1.00        42
#
#     accuracy                           0.88       195
#    macro avg       0.90      0.90      0.90       195
# weighted avg       0.88      0.88      0.88       195
#
#
# --- SVM Classification Report ---
#               precision    recall  f1-score   support
#
#            1       0.88      0.85      0.86        78
#            2       0.85      0.88      0.86        75
#            3       1.00      1.00      1.00        42
#
#     accuracy                           0.89       195
#    macro avg       0.91      0.91      0.91       195
# weighted avg       0.89      0.89      0.89       195

# %%
# Select the top x_features based on feature importance
features_sorted = df_importance['Feature'].tolist()

### training loop (for hyperparameter-tuning) - > (n_feat, n_estimators, max_depth)
log_results = []

param_grid_rf = {
    'n_estimators': [10, 50, 100],
    'max_depth': [5, 10, 20]
}

param_combinations = list(ParameterGrid(param_grid_rf))

for i in range(1, len(features_sorted) + 1):
    selected_features = features_sorted[:i]

    # select x train
    X_sel_train = X_train_df[selected_features]
    X_sel_test = X_test_df[selected_features]

    # scaler by StandardScaler
    scaler = StandardScaler()
    X_sel_train_scaled = scaler.fit_transform(X_sel_train)
    X_sel_test_scaled = scaler.transform(X_sel_test)

    for params in param_combinations:
            rf_model = RandomForestClassifier(**params, random_state=42)
            rf_model.fit(X_sel_train_scaled, y_train_df)

            y_pred = rf_model.predict(X_sel_test_scaled)
            acc = accuracy_score(y_test_df, y_pred)

            log_results.append({
                'Top_Features_Used': i,
                'Selected_Features': selected_features,
                'Params': params,
                'Accuracy': acc
            })

            print(f"Features : Top {i} | Params: {params} | Accuracy: {acc:.4f}")
    print('---'*30)
# Out:
# Features : Top 1 | Params: {'max_depth': 5, 'n_estimators': 10} | Accuracy: 0.7949
# Features : Top 1 | Params: {'max_depth': 5, 'n_estimators': 50} | Accuracy: 0.7949
# Features : Top 1 | Params: {'max_depth': 5, 'n_estimators': 100} | Accuracy: 0.7949
# Features : Top 1 | Params: {'max_depth': 10, 'n_estimators': 10} | Accuracy: 0.7744
# Features : Top 1 | Params: {'max_depth': 10, 'n_estimators': 50} | Accuracy: 0.7949
# Features : Top 1 | Params: {'max_depth': 10, 'n_estimators': 100} | Accuracy: 0.7949
# Features : Top 1 | Params: {'max_depth': 20, 'n_estimators': 10} | Accuracy: 0.7590
# Features : Top 1 | Params: {'max_depth': 20, 'n_estimators': 50} | Accuracy: 0.7795
# Features : Top 1 | Params: {'max_depth': 20, 'n_estimators': 100} | Accuracy: 0.7795
# ------------------------------------------------------------------------------------------
# Features : Top 2 | Params: {'max_depth': 5, 'n_estimators': 10} | Accuracy: 0.9231
# Features : Top 2 | Params: {'max_depth': 5, 'n_estimators': 50} | Accuracy: 0.9231
# Features : Top 2 | Params: {'max_depth': 5, 'n_estimators': 100} | Accuracy: 0.9231
# Features : Top 2 | Params: {'max_depth': 10, 'n_estimators': 10} | Accuracy: 0.9179
# Features : Top 2 | Params: {'max_depth': 10, 'n_estimators': 50} | Accuracy: 0.9179
# Features : Top 2 | Params: {'max_depth': 10, 'n_estimators': 100} | Accuracy: 0.9026
# Features : Top 2 | Params: {'max_depth': 20, 'n_estimators': 10} | Accuracy: 0.9026
# Features : Top 2 | Params: {'max_depth': 20, 'n_estimators': 50} | Accuracy: 0.8974
# Features : Top 2 | Params: {'max_depth': 20, 'n_estimators': 100} | Accuracy: 0.9026
# ------------------------------------------------------------------------------------------
# Features : Top 3 | Params: {'max_depth': 5, 'n_estimators': 10} | Accuracy: 0.9128
# Features : Top 3 | Params: {'max_depth': 5, 'n_estimators': 50} | Accuracy: 0.9231
# Features : Top 3 | Params: {'max_depth': 5, 'n_estimators': 100} | Accuracy: 0.9231
# Features : Top 3 | Params: {'max_depth': 10, 'n_estimators': 10} | Accuracy: 0.8872
# Features : Top 3 | Params: {'max_depth': 10, 'n_estimators': 50} | Accuracy: 0.9128
# Features : Top 3 | Params: {'max_depth': 10, 'n_estimators': 100} | Accuracy: 0.8974
# Features : Top 3 | Params: {'max_depth': 20, 'n_estimators': 10} | Accuracy: 0.8667
# Features : Top 3 | Params: {'max_depth': 20, 'n_estimators': 50} | Accuracy: 0.8769
# Features : Top 3 | Params: {'max_depth': 20, 'n_estimators': 100} | Accuracy: 0.8718
# ------------------------------------------------------------------------------------------
# Features : Top 4 | Params: {'max_depth': 5, 'n_estimators': 10} | Accuracy: 0.9128
# Features : Top 4 | Params: {'max_depth': 5, 'n_estimators': 50} | Accuracy: 0.9179
# Features : Top 4 | Params: {'max_depth': 5, 'n_estimators': 100} | Accuracy: 0.9179
# Features : Top 4 | Params: {'max_depth': 10, 'n_estimators': 10} | Accuracy: 0.8974
# Features : Top 4 | Params: {'max_depth': 10, 'n_estimators': 50} | Accuracy: 0.9026
# Features : Top 4 | Params: {'max_depth': 10, 'n_estimators': 100} | Accuracy: 0.9077
# Features : Top 4 | Params: {'max_depth': 20, 'n_estimators': 10} | Accuracy: 0.8821
# Features : Top 4 | Params: {'max_depth': 20, 'n_estimators': 50} | Accuracy: 0.8923
# Features : Top 4 | Params: {'max_depth': 20, 'n_estimators': 100} | Accuracy: 0.8923
# ------------------------------------------------------------------------------------------
# Features : Top 5 | Params: {'max_depth': 5, 'n_estimators': 10} | Accuracy: 0.9128
# Features : Top 5 | Params: {'max_depth': 5, 'n_estimators': 50} | Accuracy: 0.9179
# Features : Top 5 | Params: {'max_depth': 5, 'n_estimators': 100} | Accuracy: 0.9179
# Features : Top 5 | Params: {'max_depth': 10, 'n_estimators': 10} | Accuracy: 0.8872
# Features : Top 5 | Params: {'max_depth': 10, 'n_estimators': 50} | Accuracy: 0.9128
# Features : Top 5 | Params: {'max_depth': 10, 'n_estimators': 100} | Accuracy: 0.9128
# Features : Top 5 | Params: {'max_depth': 20, 'n_estimators': 10} | Accuracy: 0.8718
# Features : Top 5 | Params: {'max_depth': 20, 'n_estimators': 50} | Accuracy: 0.8872
# Features : Top 5 | Params: {'max_depth': 20, 'n_estimators': 100} | Accuracy: 0.8872
# ------------------------------------------------------------------------------------------
# Features : Top 6 | Params: {'max_depth': 5, 'n_estimators': 10} | Accuracy: 0.9231
# Features : Top 6 | Params: {'max_depth': 5, 'n_estimators': 50} | Accuracy: 0.9128
# Features : Top 6 | Params: {'max_depth': 5, 'n_estimators': 100} | Accuracy: 0.9179
# Features : Top 6 | Params: {'max_depth': 10, 'n_estimators': 10} | Accuracy: 0.8974
# Features : Top 6 | Params: {'max_depth': 10, 'n_estimators': 50} | Accuracy: 0.9179
# Features : Top 6 | Params: {'max_depth': 10, 'n_estimators': 100} | Accuracy: 0.9077
# Features : Top 6 | Params: {'max_depth': 20, 'n_estimators': 10} | Accuracy: 0.8821
# Features : Top 6 | Params: {'max_depth': 20, 'n_estimators': 50} | Accuracy: 0.9026
# Features : Top 6 | Params: {'max_depth': 20, 'n_estimators': 100} | Accuracy: 0.8923
# ------------------------------------------------------------------------------------------
# Features : Top 7 | Params: {'max_depth': 5, 'n_estimators': 10} | Accuracy: 0.9128
# Features : Top 7 | Params: {'max_depth': 5, 'n_estimators': 50} | Accuracy: 0.9128
# Features : Top 7 | Params: {'max_depth': 5, 'n_estimators': 100} | Accuracy: 0.9179
# Features : Top 7 | Params: {'max_depth': 10, 'n_estimators': 10} | Accuracy: 0.9128
# Features : Top 7 | Params: {'max_depth': 10, 'n_estimators': 50} | Accuracy: 0.9128
# Features : Top 7 | Params: {'max_depth': 10, 'n_estimators': 100} | Accuracy: 0.9077
# Features : Top 7 | Params: {'max_depth': 20, 'n_estimators': 10} | Accuracy: 0.9077
# Features : Top 7 | Params: {'max_depth': 20, 'n_estimators': 50} | Accuracy: 0.9128
# Features : Top 7 | Params: {'max_depth': 20, 'n_estimators': 100} | Accuracy: 0.9026
# ------------------------------------------------------------------------------------------
# Features : Top 8 | Params: {'max_depth': 5, 'n_estimators': 10} | Accuracy: 0.9128
# Features : Top 8 | Params: {'max_depth': 5, 'n_estimators': 50} | Accuracy: 0.9077
# Features : Top 8 | Params: {'max_depth': 5, 'n_estimators': 100} | Accuracy: 0.9128
# Features : Top 8 | Params: {'max_depth': 10, 'n_estimators': 10} | Accuracy: 0.9077
# Features : Top 8 | Params: {'max_depth': 10, 'n_estimators': 50} | Accuracy: 0.9026
# Features : Top 8 | Params: {'max_depth': 10, 'n_estimators': 100} | Accuracy: 0.9128
# Features : Top 8 | Params: {'max_depth': 20, 'n_estimators': 10} | Accuracy: 0.8821
# Features : Top 8 | Params: {'max_depth': 20, 'n_estimators': 50} | Accuracy: 0.8974
# Features : Top 8 | Params: {'max_depth': 20, 'n_estimators': 100} | Accuracy: 0.8974
# ------------------------------------------------------------------------------------------
# Features : Top 9 | Params: {'max_depth': 5, 'n_estimators': 10} | Accuracy: 0.9128
# Features : Top 9 | Params: {'max_depth': 5, 'n_estimators': 50} | Accuracy: 0.9179
# Features : Top 9 | Params: {'max_depth': 5, 'n_estimators': 100} | Accuracy: 0.9179
# Features : Top 9 | Params: {'max_depth': 10, 'n_estimators': 10} | Accuracy: 0.8974
# Features : Top 9 | Params: {'max_depth': 10, 'n_estimators': 50} | Accuracy: 0.9077
# Features : Top 9 | Params: {'max_depth': 10, 'n_estimators': 100} | Accuracy: 0.9128
# Features : Top 9 | Params: {'max_depth': 20, 'n_estimators': 10} | Accuracy: 0.8872
# Features : Top 9 | Params: {'max_depth': 20, 'n_estimators': 50} | Accuracy: 0.9282
# Features : Top 9 | Params: {'max_depth': 20, 'n_estimators': 100} | Accuracy: 0.9231
# ------------------------------------------------------------------------------------------
# Features : Top 10 | Params: {'max_depth': 5, 'n_estimators': 10} | Accuracy: 0.9128
# Features : Top 10 | Params: {'max_depth': 5, 'n_estimators': 50} | Accuracy: 0.9179
# Features : Top 10 | Params: {'max_depth': 5, 'n_estimators': 100} | Accuracy: 0.9179
# Features : Top 10 | Params: {'max_depth': 10, 'n_estimators': 10} | Accuracy: 0.8974
# Features : Top 10 | Params: {'max_depth': 10, 'n_estimators': 50} | Accuracy: 0.8923
# Features : Top 10 | Params: {'max_depth': 10, 'n_estimators': 100} | Accuracy: 0.9077
# Features : Top 10 | Params: {'max_depth': 20, 'n_estimators': 10} | Accuracy: 0.8769
# Features : Top 10 | Params: {'max_depth': 20, 'n_estimators': 50} | Accuracy: 0.9077
# Features : Top 10 | Params: {'max_depth': 20, 'n_estimators': 100} | Accuracy: 0.8923
# ------------------------------------------------------------------------------------------
# Features : Top 11 | Params: {'max_depth': 5, 'n_estimators': 10} | Accuracy: 0.8974
# Features : Top 11 | Params: {'max_depth': 5, 'n_estimators': 50} | Accuracy: 0.9128
# Features : Top 11 | Params: {'max_depth': 5, 'n_estimators': 100} | Accuracy: 0.9128
# Features : Top 11 | Params: {'max_depth': 10, 'n_estimators': 10} | Accuracy: 0.8923
# Features : Top 11 | Params: {'max_depth': 10, 'n_estimators': 50} | Accuracy: 0.9077
# Features : Top 11 | Params: {'max_depth': 10, 'n_estimators': 100} | Accuracy: 0.8974
# Features : Top 11 | Params: {'max_depth': 20, 'n_estimators': 10} | Accuracy: 0.8872
# Features : Top 11 | Params: {'max_depth': 20, 'n_estimators': 50} | Accuracy: 0.9128
# Features : Top 11 | Params: {'max_depth': 20, 'n_estimators': 100} | Accuracy: 0.9077
# ------------------------------------------------------------------------------------------
# Features : Top 12 | Params: {'max_depth': 5, 'n_estimators': 10} | Accuracy: 0.9179
# Features : Top 12 | Params: {'max_depth': 5, 'n_estimators': 50} | Accuracy: 0.9179
# Features : Top 12 | Params: {'max_depth': 5, 'n_estimators': 100} | Accuracy: 0.9179
# Features : Top 12 | Params: {'max_depth': 10, 'n_estimators': 10} | Accuracy: 0.8923
# Features : Top 12 | Params: {'max_depth': 10, 'n_estimators': 50} | Accuracy: 0.9026
# Features : Top 12 | Params: {'max_depth': 10, 'n_estimators': 100} | Accuracy: 0.9077
# Features : Top 12 | Params: {'max_depth': 20, 'n_estimators': 10} | Accuracy: 0.8872
# Features : Top 12 | Params: {'max_depth': 20, 'n_estimators': 50} | Accuracy: 0.8974
# Features : Top 12 | Params: {'max_depth': 20, 'n_estimators': 100} | Accuracy: 0.9128
# ------------------------------------------------------------------------------------------
# Features : Top 13 | Params: {'max_depth': 5, 'n_estimators': 10} | Accuracy: 0.9026
# Features : Top 13 | Params: {'max_depth': 5, 'n_estimators': 50} | Accuracy: 0.9077
# Features : Top 13 | Params: {'max_depth': 5, 'n_estimators': 100} | Accuracy: 0.9179
# Features : Top 13 | Params: {'max_depth': 10, 'n_estimators': 10} | Accuracy: 0.9026
# Features : Top 13 | Params: {'max_depth': 10, 'n_estimators': 50} | Accuracy: 0.9128
# Features : Top 13 | Params: {'max_depth': 10, 'n_estimators': 100} | Accuracy: 0.9128
# Features : Top 13 | Params: {'max_depth': 20, 'n_estimators': 10} | Accuracy: 0.8667
# Features : Top 13 | Params: {'max_depth': 20, 'n_estimators': 50} | Accuracy: 0.8923
# Features : Top 13 | Params: {'max_depth': 20, 'n_estimators': 100} | Accuracy: 0.9077
# ------------------------------------------------------------------------------------------
# Features : Top 14 | Params: {'max_depth': 5, 'n_estimators': 10} | Accuracy: 0.9077
# Features : Top 14 | Params: {'max_depth': 5, 'n_estimators': 50} | Accuracy: 0.9077
# Features : Top 14 | Params: {'max_depth': 5, 'n_estimators': 100} | Accuracy: 0.9077
# Features : Top 14 | Params: {'max_depth': 10, 'n_estimators': 10} | Accuracy: 0.8974
# Features : Top 14 | Params: {'max_depth': 10, 'n_estimators': 50} | Accuracy: 0.8974
# Features : Top 14 | Params: {'max_depth': 10, 'n_estimators': 100} | Accuracy: 0.9077
# Features : Top 14 | Params: {'max_depth': 20, 'n_estimators': 10} | Accuracy: 0.8769
# Features : Top 14 | Params: {'max_depth': 20, 'n_estimators': 50} | Accuracy: 0.9077
# Features : Top 14 | Params: {'max_depth': 20, 'n_estimators': 100} | Accuracy: 0.8974
# ------------------------------------------------------------------------------------------

# %%
import pandas as pd

# trans log_results to DataFrame
df_log = pd.DataFrame(log_results)

# select top 10 acc
top10_logs = df_log.sort_values(by='Accuracy', ascending=False).head(10)
top10_logs
# Out:
#     Top_Features_Used                                  Selected_Features  \
# 79                  9  [Session_Duration (hours), Workout_Frequency (...
# 10                  2  [Session_Duration (hours), Workout_Frequency (...
# 11                  2  [Session_Duration (hours), Workout_Frequency (...
# 20                  3  [Session_Duration (hours), Workout_Frequency (...
# 19                  3  [Session_Duration (hours), Workout_Frequency (...
# 9                   2  [Session_Duration (hours), Workout_Frequency (...
# 80                  9  [Session_Duration (hours), Workout_Frequency (...
# 45                  6  [Session_Duration (hours), Workout_Frequency (...
# 28                  4  [Session_Duration (hours), Workout_Frequency (...
# 29                  4  [Session_Duration (hours), Workout_Frequency (...
#
#                                     Params  Accuracy
# 79   {'max_depth': 20, 'n_estimators': 50}  0.928205
# 10    {'max_depth': 5, 'n_estimators': 50}  0.923077
# 11   {'max_depth': 5, 'n_estimators': 100}  0.923077
# 20   {'max_depth': 5, 'n_estimators': 100}  0.923077
# 19    {'max_depth': 5, 'n_estimators': 50}  0.923077
# 9     {'max_depth': 5, 'n_estimators': 10}  0.923077
# 80  {'max_depth': 20, 'n_estimators': 100}  0.923077
# 45    {'max_depth': 5, 'n_estimators': 10}  0.923077
# 28    {'max_depth': 5, 'n_estimators': 50}  0.917949
# 29   {'max_depth': 5, 'n_estimators': 100}  0.917949

# %%
from sklearn.metrics import classification_report, confusion_matrix

### train model (grid scarch + top 4 feat)
def rf_select_feat(feat = 3):

    # rand param
    n_estimators_list = [10, 50, 100, 150, 200]
    max_depth_list = [5, 10, 15, 20, 25]

    # select top features
    features_sorted = df_importance.sort_values(by='Importance', ascending=False)['Feature'].tolist()
    selected_features = features_sorted[:feat]

    X_sel_train = X_train_df[selected_features]
    X_sel_test = X_test_df[selected_features]

    scaler = StandardScaler()
    X_sel_train_scaled = scaler.fit_transform(X_sel_train)
    X_sel_test_scaled = scaler.transform(X_sel_test)

    results = []

    for max_depth in max_depth_list:
        for n_estimators in n_estimators_list:
            model = RandomForestClassifier(n_estimators=n_estimators,
                                          max_depth=max_depth,
                                          random_state=42)
            model.fit(X_sel_train_scaled, y_train_df)
            y_pred = model.predict(X_sel_test_scaled)
            acc = accuracy_score(y_test_df, y_pred)

            results.append({
                'n_estimators': n_estimators,
                'max_depth': max_depth,
                'Accuracy': acc,
                'Model': model
            })
            # print(f"n_estimators={n_estimators}, max_depth={max_depth} => Accuracy: {acc:.4f}")

    df_results = pd.DataFrame(results)

    # find model top acc สูงสุด
    top_acc_row = df_results.loc[df_results['Accuracy'].idxmax()]

    # Plot Line Chart
    plt.figure(figsize=(10, 6))
    for depth in max_depth_list:
        subset = df_results[df_results['max_depth'] == depth]
        plt.plot(subset['n_estimators'], subset['Accuracy'], marker='o', label=f'max_depth={depth}')

    plt.title(f"Accuracy vs. n_estimators (Top {feat} Features)")
    plt.xlabel("n_estimators")
    plt.ylabel("Accuracy")
    plt.ylim(0, 1)
    plt.grid(True)
    plt.legend(title="max_depth")
    plt.ylim(0.8, 1)  # startwith 0.8
    plt.tight_layout()
    plt.show()

    print('---'*30)
    print('Best Model')
    best_model = top_acc_row['Model']
    print(f"Top Accuracy: {top_acc_row['Accuracy']:.4f}")
    print(f"Best parameters -> n_estimators: {top_acc_row['n_estimators']}, max_depth: {top_acc_row['max_depth']}")

    # Classification Report
    print("\nClassification Report:")
    print(classification_report(y_test_df, best_model.predict(X_sel_test_scaled)))
    print('---'*30)

    # Confusion Matrix
    cm = confusion_matrix(y_test_df, best_model.predict(X_sel_test_scaled))
    print(cm)

    # heatmap (cm)
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title('Confusion Matrix (Heatmap)')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.tight_layout()
    plt.show()

# call func
rf_select_feat(3)
# # Confusion Matrix
#     print("\nConfusion Matrix:")
#     cm = confusion_matrix(y_test_df, best_model.predict(X_sel_test_scaled))
#     print(cm)
# Out:
# ------------------------------------------------------------------------------------------
# Best Model
# Top Accuracy: 0.9231
# Best parameters -> n_estimators: 50, max_depth: 5
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      0.81      0.89        78
#            2       0.83      1.00      0.91        75
#            3       1.00      1.00      1.00        42
#
#     accuracy                           0.92       195
#    macro avg       0.94      0.94      0.93       195
# weighted avg       0.94      0.92      0.92       195
#
# ------------------------------------------------------------------------------------------
# [[63 15  0]
#  [ 0 75  0]
#  [ 0  0 42]]

# %%
# ### MLP
# # import torch
# # import torch.nn as nn
# # import torch.optim as optim
# # from sklearn.model_selection import train_test_split
# # from sklearn.preprocessing import StandardScaler
# # from sklearn.metrics import accuracy_score

# # Standardize the data
# scaler = StandardScaler()
# X_train_scaled = scaler.fit_transform(X_train_df)
# X_test_scaled = scaler.transform(X_test_df)

# X_train_final, X_val, y_train_final, y_val = train_test_split(
#     X_train_scaled, y_train_df.values, test_size=0.2, random_state=42
# )

# # Convert to PyTorch tensors
# X_train_tensor = torch.FloatTensor(X_train_final)
# y_train_tensor = torch.LongTensor(y_train_final)
# X_val_tensor = torch.FloatTensor(X_val)
# y_val_tensor = torch.LongTensor(y_val)
# X_test_tensor = torch.FloatTensor(X_test_scaled)
# y_test_tensor = torch.LongTensor(y_test_df.values)

# # Define MLP model
# class ImprovedMLP(nn.Module):
#     def __init__(self, input_size, hidden_size, num_classes):
#         super(ImprovedMLP, self).__init__()
#         self.model = nn.Sequential(
#             nn.Linear(input_size, hidden_size),
#             nn.BatchNorm1d(hidden_size),
#             nn.ReLU(),
#             nn.Dropout(0.3),
#             nn.Linear(hidden_size, hidden_size),
#             nn.BatchNorm1d(hidden_size),
#             nn.ReLU(),
#             nn.Dropout(0.3),
#             nn.Linear(hidden_size, num_classes)
#         )

#     def forward(self, x):
#         return self.model(x)

# # Set hyperparameters
# input_size = X_train_df.shape[1]
# num_classes = len(y_train_df.unique())
# hidden_size = 64
# learning_rate = 0.005
# num_epochs = 150

# # Initialize model, loss function, and optimizer
# model = ImprovedMLP(input_size, hidden_size, num_classes)
# criterion = nn.CrossEntropyLoss()
# optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# train_losses = []
# val_losses = []
# best_val_acc = 0.0
# best_model_state = None

# # Train the model
# for epoch in range(num_epochs):
#     model.train()
#     outputs = model(X_train_tensor)
#     loss = criterion(outputs, y_train_tensor)

#     optimizer.zero_grad()
#     loss.backward()
#     optimizer.step()

#     # Validate
#     model.eval()
#     with torch.no_grad():
#         val_outputs = model(X_val_tensor)
#         val_loss = criterion(val_outputs, y_val_tensor)
#         _, val_preds = torch.max(val_outputs, 1)
#         val_acc = accuracy_score(y_val_tensor, val_preds)

#     train_losses.append(loss.item())
#     val_losses.append(val_loss.item())

#     if val_acc > best_val_acc:
#         best_val_acc = val_acc
#         best_model_state = model.state_dict()

#     print(f"Epoch {epoch+1:3d}: Train Loss={loss.item():.4f}, Val Loss={val_loss.item():.4f}, Val Acc={val_acc:.4f}")

# # Load the best model
# model.load_state_dict(best_model_state)

# # Evaluate on the test set
# model.eval()
# with torch.no_grad():
#     test_outputs = model(X_test_tensor)
#     _, test_preds = torch.max(test_outputs, 1)
#     test_acc = accuracy_score(y_test_tensor, test_preds)
# print(f"\nBest Validation Accuracy = {best_val_acc:.4f}, Test Accuracy = {test_acc:.4f}")

# # Plot training and validation loss
# plt.figure(figsize=(10, 5))
# plt.plot(train_losses, label='Train Loss')
# plt.plot(val_losses, label='Validation Loss')
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.title('Train vs Validation Loss')
# plt.legend()
# plt.grid(True)
# plt.tight_layout()
# plt.show()

# # Display the last 10 epochs of loss
# loss_df = pd.DataFrame({
#     'Epoch': list(range(1, num_epochs + 1)),
#     'Train_Loss': train_losses,
#     'Val_Loss': val_losses
# })
# print("\nLast 10 Epoch Losses:")
# print(loss_df.tail(10))

# %%
df.head()
# Out:
#    Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0   56    Male         88.3        1.71      180      157           60
# 1   46  Female         74.9        1.53      179      151           66
# 2   32  Female         68.1        1.66      167      122           54
# 3   25    Male         53.2        1.70      190      164           56
# 4   38    Male         46.1        1.79      188      158           68
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                      1.69           1313.0         Yoga            12.6
# 1                      1.30            883.0         HIIT            33.9
# 2                      1.11            677.0       Cardio            33.4
# 3                      0.59            532.0     Strength            28.8
# 4                      0.64            556.0     Strength            29.2
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# 0                    3.5                              4                 3
# 1                    2.1                              4                 2
# 2                    2.3                              4                 2
# 3                    2.1                              3                 1
# 4                    2.8                              3                 1
#
#      BMI
# 0  30.20
# 1  32.00
# 2  24.71
# 3  18.41
# 4  14.39

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 973 entries, 0 to 972
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            973 non-null    int64
#  1   Gender                         973 non-null    object
#  2   Weight (kg)                    973 non-null    float64
#  3   Height (m)                     973 non-null    float64
#  4   Max_BPM                        973 non-null    int64
#  5   Avg_BPM                        973 non-null    int64
#  6   Resting_BPM                    973 non-null    int64
#  7   Session_Duration (hours)       973 non-null    float64
#  8   Calories_Burned                973 non-null    float64
#  9   Workout_Type                   973 non-null    object
#  10  Fat_Percentage                 973 non-null    float64
#  11  Water_Intake (liters)          973 non-null    float64
#  12  Workout_Frequency (days/week)  973 non-null    int64
#  13  Experience_Level               973 non-null    int64
#  14  BMI                            973 non-null    float64
# dtypes: float64(7), int64(6), object(2)
# memory usage: 114.2+ KB

# %%
## Feature Engineering

# Heart Rate Ratio (Avg_BPM / Max_BPM) -> ความหนักของการออกกำลังกาย
df['Heart_Rate_Ratio'] = df['Avg_BPM'] / (df['Max_BPM'] + 1e-6)

# Weight to Height Ratio
df['Weight_to_Height_Ratio'] = df['Weight (kg)'] / (df['Height (m)'] + 1e-6)

# Fat Percentage to Water Intake Ratio
df['Fat_Percentage_to_Water_Ratio'] = df['Fat_Percentage'] / (df['Water_Intake (liters)'] + 1e-6)

# Consistency_Score -> (ความสม่ำเสมอในการออกกำลัง)
df['Consistency_Score (hours/week)'] = df['Workout_Frequency (days/week)'] * df['Session_Duration (hours)']

# Intensity_Score -> เทียบจาก Calories_Burned
df['Intensity_Score (cal/hours)'] = df['Calories_Burned'] / (df['Session_Duration (hours)'] + 1e-6)

df.head()
# Out:
#    Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0   56    Male         88.3        1.71      180      157           60
# 1   46  Female         74.9        1.53      179      151           66
# 2   32  Female         68.1        1.66      167      122           54
# 3   25    Male         53.2        1.70      190      164           56
# 4   38    Male         46.1        1.79      188      158           68
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                      1.69           1313.0         Yoga            12.6
# 1                      1.30            883.0         HIIT            33.9
# 2                      1.11            677.0       Cardio            33.4
# 3                      0.59            532.0     Strength            28.8
# 4                      0.64            556.0     Strength            29.2
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# 0                    3.5                              4                 3
# 1                    2.1                              4                 2
# 2                    2.3                              4                 2
# 3                    2.1                              3                 1
# 4                    2.8                              3                 1
#
#      BMI  Heart_Rate_Ratio  Weight_to_Height_Ratio  \
# 0  30.20          0.872222               51.637397
# 1  32.00          0.843575               48.954216
# 2  24.71          0.730539               41.024072
# 3  18.41          0.863158               31.294099
# 4  14.39          0.840426               25.754176
#
#    Fat_Percentage_to_Water_Ratio  Consistency_Score (hours/week)  \
# 0                       3.599999                            6.76
# 1                      16.142849                            5.20
# 2                      14.521733                            4.44
# 3                      13.714279                            1.77
# 4                      10.428568                            1.92
#
#    Intensity_Score (cal/hours)
# 0                   776.922617
# 1                   679.230247
# 2                   609.909360
# 3                   901.693387
# 4                   868.748643

# %%
# select feat (from feature engineering)
selected_features = ['Intensity_Score (cal/hours)', 'Fat_Percentage_to_Water_Ratio', 'Consistency_Score (hours/week)']
X = df[selected_features]

plt.figure(figsize=(18, 5))
for i, feature in enumerate(selected_features):
    plt.subplot(1, 3, i+1)
    sns.histplot(X[feature], kde=True, bins=30, color='skyblue')
    plt.title(f'Distribution of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import plotly.express as px

selected_features = ['Intensity_Score (cal/hours)', 'Fat_Percentage_to_Water_Ratio', 'Consistency_Score (hours/week)']
X = df[selected_features]

# Scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Use matric (find best k)
inertia = []
silhouette_scores = []

for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, random_state=42, max_iter=1000)
    cluster_labels = kmeans.fit_predict(X_scaled)
    inertia.append(kmeans.inertia_)
    silhouette_scores.append(silhouette_score(X_scaled, cluster_labels))

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.plot(range(2, 11), inertia, marker='o')
plt.title('KMeans Inertia for Different Values of k')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(range(2, 11), silhouette_scores, marker='o', color='orange')
plt.title('Silhouette Scores for Different Values of k')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# K = 4
kmeans = KMeans(n_clusters=4, random_state=42)
df['Segment'] = kmeans.fit_predict(X_scaled)

X_scaled_df = pd.DataFrame(X_scaled, columns=['Intensity_Score (cal/hours)', 'Fat_Percentage_to_Water_Ratio', 'Consistency_Score (hours/week)'])
X_scaled_df['Segment'] = df['Segment'].astype(str)

fig = px.scatter_3d(
    X_scaled_df,
    x='Intensity_Score (cal/hours)',
    y='Fat_Percentage_to_Water_Ratio',
    z='Consistency_Score (hours/week)',
    color='Segment',
    title='Interactive 3D Customer Segmentation',
    opacity=0.8
)

fig.update_layout(legend_title_text='Segment', margin=dict(l=0, r=0, b=0, t=30))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1f921d0e-2d7e-4b42-90a4-3dec4934b679" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1f921d0e-2d7e-4b42-90a4-3dec4934b679")) {                    Plotly.newPlot(                        "1f921d0e-2d7e-4b42-90a4-3dec4934b679",                        [{"hovertemplate":"Segment=0\u003cbr\u003eIntensity_Score (cal\u002fhours)=%{x}\u003cbr\u003eFat_Percentage_to_Water_Ratio=%{y}\u003cbr\u003eConsistency_Score (hours\u002fweek)=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","marker":{"color":"#636efa","opacity":0.8,"symbol":"circle"},"mode":"markers","name":"0","scene":"scene","showlegend":true,"x":[0.6502590136724573,-0.21330382427972558,-0.25036326396576686,-0.5437853024779901,1.0748418428380708,-0.4831074850522262,-0.36595407896466253,0.2516316566189571,-0.007181949184811452,0.8869268162609666,0.34359161697651547,-1.6120582752563228,-0.5242709872047647,-0.9914817606506724,1.7745155173108775,-0.4204339009595372,1.2020973772832833,0.510791104086562,0.9952118852448625,0.48265348563413496,0.5076883518077049,0.9498911870214697,1.646083989899589,0.305538308574665,1.5234386498130055,0.7652065760379068,-1.195202781272596,1.224241863308508,-1.5039141819774486,-0.08841187151080153,-0.3166922194451284,-1.2474835412665997,0.7568410913902365,-0.3151413509800602,-0.20512586222380116,-0.3494677102198435,1.5813995256624298,-0.06269611925257541,-0.6320981388000447,-0.3663656250236414,-0.061424191535775614,0.2253267851886904,0.06110989915613166,-1.0399906056612844,0.8235276272156276,-0.1470544134978333,-0.030420241016213375,-1.0966238234654784,0.7970431454294254,-1.8174504930978075,-0.37121430456281235,-0.26530418112065723,0.054462063337104065,-0.9921630415728472,-1.210619346539535,-1.1018997886256272,-0.3700346880511943,-0.007687715688665634,0.45312586066587535,-0.944196042878926,-0.17988690459029524,0.2555129903619971,-1.868308430407809,-0.02861323546258565,-1.9706387432990964,0.9917233438221472,-0.8713756846779528,0.10040940116564509,-0.06209011561057176,-1.0981623858987846,-1.50815689490835,-1.1136309754361724,0.8249853090335172,-0.5808715768578635,-0.5681620396424029,0.34041267163920863,0.1681084442700521,0.3802214049574716,0.4275992217260865,0.8879423098708195,-1.041870404145753,-0.575325491197865,-1.2258249300890496,-2.0775859075828107,-0.36953441539746884,-2.0737480030578395,-0.50355156619336,-0.1768929195952431,0.37877441859645383,-1.385878085137257,-0.147010897307715,0.7628027323979287,0.972674429117201,1.9655279483646797,0.3105191454572483,1.269419425176179,-0.546426995016538,-0.9981545183023451,1.8377051997382643,-0.17902966620207147,0.38109982623983085,-0.18648771042632542,0.7103313413981351,0.44623845694933606,0.36967148974486236,0.19504088042091555,0.9347090504130372,-0.18681375214679335,1.8389923367104442,0.4584485924809778,1.2051297039518785,-1.405494569401809,-1.0588571628849242,-1.2812537706463543,0.25636079431848463,0.9709730257993037,0.5979253150302261,1.0754990746470714,-0.4100023596490372,0.3831585094067308,-0.5075904679380534,-0.37522348332727573,0.2542698356165591,0.4216493095997613,0.2530046712257983,1.962635506036599,1.3953674010716741,-1.0430680238439476,1.1433377430295226,1.203556745031784,0.5106087134193631,1.2207049653763011,-1.170817498113967,-2.0267758946765992,-1.1557055549510489,2.4059035385324536,-0.2955893825106386,1.1114891283276818,-1.8147698936552332,0.05269731886748091,2.2179581057961713,1.7106352440152068,-0.8331626658489307,0.5423835924902696,-0.6981689499855231,0.5686555721832036,-0.9844149560077209,1.2208891873227612,1.012757206023813,-0.5081030631293061,-1.505137398620281,1.458577390517246,-1.4065519800953774,1.3918147663892755,-0.35139671950068985,0.3166836925993254,-0.7123629 ...

# %%
# Summarize the average values of features for each customer segment
cluster_summary = df.groupby('Segment')[['Intensity_Score (cal/hours)', 'Fat_Percentage_to_Water_Ratio', 'Consistency_Score (hours/week)']].mean().round(2)
print(cluster_summary)
# Out:
#          Intensity_Score (cal/hours)  Fat_Percentage_to_Water_Ratio  \
# Segment
# 0                             718.87                           4.95
# 1                             674.64                           9.49
# 2                             821.29                           9.66
# 3                             675.63                          15.82
#
#          Consistency_Score (hours/week)
# Segment
# 0                                  7.97
# 1                                  3.39
# 2                                  3.45
# 3                                  3.63

# %%
# count customer
cluster_counts = df['Segment'].value_counts().sort_index()

# Scale down Intensity_Score to per 100
df['Intensity_Score (100 cal/hours)'] = df['Intensity_Score (cal/hours)'] / 100.0

# Summarize the average values for each segment
cluster_summary = df.groupby('Segment')[[
    'Intensity_Score (100 cal/hours)',
    'Fat_Percentage_to_Water_Ratio',
    'Consistency_Score (hours/week)'
]].mean().round(2)


fig, ax1 = plt.subplots(figsize=(12, 8))
sns.barplot(x=cluster_counts.index, y=cluster_counts.values, ax=ax1, palette='viridis')
ax1.set_xlabel('Cluster Segment')
ax1.set_ylabel('Number of Members', color='b')
ax1.set_title('Cluster Distribution with Feature Averages')
ax2 = ax1.twinx()

# Line plot
for feature in cluster_summary.columns:
    sns.lineplot(x=cluster_summary.index, y=cluster_summary[feature], ax=ax2, marker='o', label=feature)
ax2.set_ylabel('Average Feature Values', color='g')

ax2.legend(loc='upper left', title='Features')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-234-f583a11f5433>:16: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
